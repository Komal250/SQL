# %% [markdown]
# **import the Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48db03d7-ff18-4f98-9aba-c3c92cca1e15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48db03d7-ff18-4f98-9aba-c3c92cca1e15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
Drone_data = pd.read_csv('ML-Dataset.csv')
Drone_data
Drone_data.head(5)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4  Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
#
#    Control Range             Battery Type  Weight    Price  Actual Price  \
# 0             40          Lithium Battery     200   2297.0        4999.0
# 1            300               AA Battery     500  10255.0       11000.0
# 2            102  AA Rechargeable Battery     150   1994.0        5999.0
# 3             50          Lithium Battery     150   2455.0        4999.0
# 4            200          Lithium Battery     200   4998.0        5999.0
#
#    Discount (%)
# 0          54.0
# 1           6.0
# 2          66.0
# 3          50.0
# ...

# %%
Drone_data.tail(5)
# Out:
#                                                   Name                Type  \
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#      Control Range     Battery Type  Weight   Price  Actual Price  \
# 816             60  Lithium Battery     250  2244.0        8999.0
# 817            100  Lithium Battery     350  2447.0        4999.0
# 818            102  Lithium Battery     400  1799.0        6999.0
# 819             60  Lithium Battery     250  2799.0        5999.0
# 820            100  Lithium Battery     300  2705.0        8999.0
#
#      Discount (%)
# 816          75.0
# 817          51.0
# 818          74.0
# 819          53.0
# 820          69.0

# %%
Drone_data.shape
# Out:
# (821, 8)

# %%
print("Number of all Drone =", Drone_data.shape[0])
# Out:
# Number of all Drone = 821

# %%
print("Number of all columns = ", Drone_data.shape[1])
# Out:
# Number of all columns =  8

# %%
Drone_data.dtypes
# Out:
# Name              object
# Type              object
# Control Range      int64
# Battery Type      object
# Weight             int64
# Price            float64
# Actual Price     float64
# Discount (%)     float64
# dtype: object

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Drone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           821 non-null    object
#  1   Type           821 non-null    object
#  2   Control Range  821 non-null    int64
#  3   Battery Type   821 non-null    object
#  4   Weight         821 non-null    int64
#  5   Price          813 non-null    float64
#  6   Actual Price   813 non-null    float64
#  7   Discount (%)   810 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 51.4+ KB

# %%
Drone_2 =  Drone_data[['Name','Type','Control Range','Battery Type','Weight', 'Price','Actual Price']]
Drone_2.head(4)
# Out:
#                                                 Name                Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3  Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
#
#    Control Range             Battery Type  Weight    Price  Actual Price
# 0             40          Lithium Battery     200   2297.0        4999.0
# 1            300               AA Battery     500  10255.0       11000.0
# 2            102  AA Rechargeable Battery     150   1994.0        5999.0
# 3             50          Lithium Battery     150   2455.0        4999.0

# %%
Drone_2.to_csv('Modified-Drone-Dataset.csv')

# %% [markdown]
# **Delete column from data**

# %%
Drone_3 = Drone_data.drop(columns=['Battery Type', 'Actual Price'], axis = 1)
Drone_3
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#      Control Range  Weight    Price  Discount (%)
# ...

# %%
Drone_2 = Drone_data[['Type','Control Range','Weight','Price']]
Drone_2.head(6)
# Out:
#                  Type  Control Range  Weight    Price
# 0          Mini Drone             40     200   2297.0
# 1          Mini Drone            300     500  10255.0
# 2  Professional Drone            102     150   1994.0
# 3          Mini Drone             50     150   2455.0
# 4          Mini Drone            200     200   4998.0
# 5          Mini Drone            100     200   4376.0

# %%
Drone_2.head(4)
# Out:
#                  Type  Control Range  Weight    Price
# 0          Mini Drone             40     200   2297.0
# 1          Mini Drone            300     500  10255.0
# 2  Professional Drone            102     150   1994.0
# 3          Mini Drone             50     150   2455.0

# %%
Drone_data.columns
# Out:
# Index(['Name', 'Type', 'Control Range', 'Battery Type', 'Weight', 'Price',
#        'Actual Price', 'Discount (%)'],
#       dtype='object')

# %%
Dro_dict = {'Name': "Drone_Name",
            'Type': "Drone_Type",
            'Control Range': "Range",
            'Battery Type': "Type_of_Battery",
            'Weight': "Drone_Weight",
            'Price': "Drone_Price",
            'Actual Price': "Real_Price",
            'Discount  (%)': "Discount"}

# %%
Drone_data = Drone_data.rename(columns = Dro_dict)
Drone_data.head(3)
# Out:
#                                           Drone_Name          Drone_Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
#
#    Range          Type_of_Battery  Drone_Weight  Drone_Price  Real_Price  \
# 0     40          Lithium Battery           200       2297.0      4999.0
# 1    300               AA Battery           500      10255.0     11000.0
# 2    102  AA Rechargeable Battery           150       1994.0      5999.0
#
#    Discount (%)
# 0          54.0
# 1           6.0
# 2          66.0

# %%
Drone_data.select_dtypes(include = 'object').head(3)
# Out:
#                                           Drone_Name          Drone_Type  \
# 0  Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1  Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2  Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
#
#            Type_of_Battery
# 0          Lithium Battery
# 1               AA Battery
# 2  AA Rechargeable Battery

# %%
Drone_data.select_dtypes(exclude = 'object').head(3)
# Out:
#    Range  Drone_Weight  Drone_Price  Real_Price  Discount (%)
# 0     40           200       2297.0      4999.0          54.0
# 1    300           500      10255.0     11000.0           6.0
# 2    102           150       1994.0      5999.0          66.0

# %%
categorical_col = Drone_data.select_dtypes(include = 'object').columns
categorical_col
# Out:
# Index(['Name', 'Type', 'Battery Type'], dtype='object')

# %%
categorical_col = Drone_data.select_dtypes(exclude = 'object').columns
categorical_col
# Out:
# Index(['Control Range', 'Weight', 'Price', 'Actual Price', 'Discount (%)'], dtype='object')

# %%
Drone_df = Categorical_col =Drone_data.select_dtypes(include = 'object')
Drone_df
# Out:
#                                                   Name                Type  \
# 0    Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1    Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2    Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3    Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4    Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# ..                                                 ...                 ...
# 816  Swa Mi Drone WiFi Camera Remote Control-Motion...  Professional Drone
# 817                              Radhikadro e449 Drone  Professional Drone
# 818  Mevara fOlDaBlE-ToY-DrOnE pHoToGrApHy GeStUrE-...  Professional Drone
# 819  mayuri E8 WiFi Camera Remote Control 360 Flip ...  Professional Drone
# 820  Swa Mi E88 Drone Best Adults/Kids Drone With W...  Professional Drone
#
#                 Battery Type
# 0            Lithium Battery
# ...

# %%
num_df = Categorical_col = Drone_data.select_dtypes(exclude = 'object')
num_df
# Out:
#      Control Range  Weight    Price  Actual Price  Discount (%)
# 0               40     200   2297.0        4999.0          54.0
# 1              300     500  10255.0       11000.0           6.0
# 2              102     150   1994.0        5999.0          66.0
# 3               50     150   2455.0        4999.0          50.0
# 4              200     200   4998.0        5999.0          16.0
# ..             ...     ...      ...           ...           ...
# 816             60     250   2244.0        8999.0          75.0
# 817            100     350   2447.0        4999.0          51.0
# 818            102     400   1799.0        6999.0          74.0
# 819             60     250   2799.0        5999.0          53.0
# 820            100     300   2705.0        8999.0          69.0
#
# [821 rows x 5 columns]

# %%
Categorical_col_List = list(Drone_data.select_dtypes(include = 'object').columns)
Categorical_col_List
# Out:
# ['Name', 'Type', 'Battery Type']

# %%
Numerical_col_List = list(Drone_data.select_dtypes(exclude = 'object').columns)
Numerical_col_List
# Out:
# ['Control Range', 'Weight', 'Price', 'Actual Price', 'Discount (%)']

# %%
Drone_data.duplicated().any()
# Out:
# np.True_

# %%
Drone_data.duplicated().any()
# Out:
# np.True_

# %%
Drone_data.head(20)
# Out:
#                                                  Name                Type  \
# 0   Zyamalox ZX drone with camera 4k ,12 MP ,fly 3...          Mini Drone
# 1   Fitpro M3 Ultra Beginner Drone 2.4G Mini FPV H...          Mini Drone
# 2   Clubmall E88 Pro 4K Camera Drone with WiFi FPV...  Professional Drone
# 3   Orivox A17 Aerial Drone with 4K Dual Camera - ...          Mini Drone
# 4   Orivox M3 Max Mini Drone with Pro Features HD ...          Mini Drone
# 5   ERH India A17 Aerial Drone with 4K Dual Camera...          Mini Drone
# 6   Kidsbuddy New Good Quality Quadcopter E88 WIFI...          Mini Drone
# 7   tmwilla Foldable-RC-Quadcopter-Altitude-Hold-H...  Professional Drone
# 8   CLYSOL New Good Quality Quadcopter E88 WIFI Dr...          Mini Drone
# 9   Clubics RC Brushless Motor J18 Drone 4k hd Cam...  Professional Drone
# 10  tmwilla Drone WiFi Camera Drone Remote Control...  Professional Drone
# 11                        nexell j2 black 00223 Drone  Professional Drone
# ...

# %%
Drone_data[Drone_data.duplicated()]
# Out:
#                                                   Name                Type  \
# 478  Swa Mi E88 Pro Foldable Remote Control Drone D...  Professional Drone
# 609  Swa Mi Mini dron with Camera Hd Dual Camera Wi...  Professional Drone
# 630  Swa Mi High Quality E88 Pro Drone HD, Dual Cam...  Professional Drone
#
#      Control Range     Battery Type  Weight   Price  Actual Price  \
# 478            100  Lithium Battery     100  2705.0        8999.0
# 609            100  Lithium Battery     100  2244.0        8999.0
# 630            100  Lithium Battery     100  2705.0        8999.0
#
#      Discount (%)
# 478          69.0
# 609          75.0
# 630          69.0

# %%
Drone_d2 = Drone_data.drop_duplicates()

# %%
Drone_d2.shape
# Out:
# (818, 8)

# %%
df = Drone_d2.isnull().sum().reset_index()
df.columns = ['column','null_records']
df['% null_records'] = (df['null_records']/11199)*100
df
# Out:
#           column  null_records  % null_records
# 0           Name             0        0.000000
# 1           Type             0        0.000000
# 2  Control Range             0        0.000000
# 3   Battery Type             0        0.000000
# 4         Weight             0        0.000000
# 5          Price             8        0.071435
# 6   Actual Price             8        0.071435
# 7   Discount (%)            11        0.098223

# %%
Drone_d2['Type']
# Out:
# 0              Mini Drone
# 1              Mini Drone
# 2      Professional Drone
# 3              Mini Drone
# 4              Mini Drone
#               ...
# 816    Professional Drone
# 817    Professional Drone
# 818    Professional Drone
# 819    Professional Drone
# 820    Professional Drone
# Name: Type, Length: 818, dtype: object

# %%
Drone_d2['Type'].value_counts()
# Out:
# Type
# Professional Drone    427
# Mini Drone            391
# Name: count, dtype: int64
